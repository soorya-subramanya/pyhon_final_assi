# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('myexcel.csv')

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df['Height'] = np.random.randint(150, 181, size=len(df))

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     166     235
# 2   John Holland  Boston Celtics      30       SG   27     171     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     173     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
team_distribution = df['Team'].value_counts()
team_percentage = (team_distribution / len(df)) * 100

# %% [raw]
# team_distribution, team_percentage

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=team_distribution.index, y=team_distribution.values)
plt.title('Distribution of Employees Across Teams')
plt.xlabel('Team')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# %%
position_distribution = df['Position'].value_counts()

# %%
position_distribution
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=position_distribution.index, y=position_distribution.values)
plt.title('Distribution of Employees by Position')
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# %%
bins = [20, 25, 30]
labels = ['20-24', '25-29']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# %%
age_group_distribution = df['Age Group'].value_counts()

# %%
age_group_distribution
# Out:
# Age Group
# 25-29    182
# 20-24    152
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=age_group_distribution.index, y=age_group_distribution.values)
plt.title('Distribution of Employees by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.show()

# %%
team_salary_expenditure = df.groupby('Team')['Salary'].sum()
position_salary_expenditure = df.groupby('Position')['Salary'].sum()

# %%
team_salary_expenditure.idxmax(), team_salary_expenditure.max(), position_salary_expenditure.idxmax(), position_salary_expenditure.max()
# Out:
# ('Cleveland Cavaliers', 106988689.0, 'C', 466377332.0)

# %%
plt.figure(figsize=(10, 6))
team_salary_expenditure.sort_values(ascending=False).plot(kind='bar')
plt.title('Salary Expenditure by Team')
plt.xlabel('Team')
plt.ylabel('Total Salary Expenditure')
plt.show()

# %%
plt.figure(figsize=(10, 6))
position_salary_expenditure.sort_values(ascending=False).plot(kind='bar')
plt.title('Salary Expenditure by Position')
plt.xlabel('Position')
plt.ylabel('Total Salary Expenditure')
plt.show()

# %%
correlation = df['Age'].corr(df['Salary'])

# %%
correlation
# Out:
# 0.21400941226570974

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Salary', data=df)
plt.title('Correlation Between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Team Distribution: Since all employees belong to the Boston Celtics, there's no team distribution to report.
#
# Position Segregation: The analysis of positions helps understand the role distribution within the team, which is crucial for performance and strategy planning.
#
# Predominant Age Group: Identifying the predominant age group can assist in tailoring player development and training strategies.
#
# Salary Expenditure: Understanding which positions have the highest salary expenditures can inform financial planning and contract negotiations.
#
# Age and Salary Correlation: Investigating the relationship between age and salary can reveal how experience (age) correlates with compensation, potentially highlighting areas for pay equity improvements.
